# %% [markdown]
# # Task 1 : Data Overview

# %% [markdown]
# ## Understand the dataset structure.

# %%
import pandas as pd

# %%
file_path = "Data_set 2 - Copy.csv"
df = pd.read_csv(file_path)

# %%
df.head() #printing the first five rows of the dataset
# Out:
#    gender  age Investment_Avenues  Mutual_Funds  Equity_Market  Debentures  \
# 0  Female   34                Yes             1              2           5
# 1  Female   23                Yes             4              3           2
# 2    Male   30                Yes             3              6           4
# 3    Male   22                Yes             2              1           3
# 4  Female   24                 No             2              1           3
#
#    Government_Bonds  Fixed_Deposits  PPF  Gold  ...           Duration  \
# 0                 3               7    6     4  ...          1-3 years
# 1                 1               5    6     7  ...  More than 5 years
# 2                 2               5    1     7  ...          3-5 years
# 3                 7               6    4     5  ...   Less than 1 year
# 4                 6               4    5     7  ...   Less than 1 year
#
#   Invest_Monitor   Expect       Avenue What are your savings objectives?  \
# ...

# %%
df.tail() #printing the last five rows of the dataset
# Out:
#    gender  age Investment_Avenues  Mutual_Funds  Equity_Market  Debentures  \
# 35   Male   30                Yes             1              4           6
# 36   Male   30                Yes             2              4           7
# 37   Male   25                Yes             5              4           7
# 38   Male   31                Yes             2              4           7
# 39   Male   29                Yes             4              3           5
#
#     Government_Bonds  Fixed_Deposits  PPF  Gold  ...   Duration  \
# 35                 5               3    2     7  ...  3-5 years
# 36                 5               1    3     6  ...  1-3 years
# 37                 6               1    2     3  ...  3-5 years
# 38                 5               3    1     6  ...  1-3 years
# 39                 7               2    1     6  ...  3-5 years
#
#    Invest_Monitor   Expect                 Avenue  \
# 35        Monthly  20%-30%         Fixed Deposits
# ...

# %%
print("\nDataset Info:")
df.info()
# Out:
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 24 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   gender                             40 non-null     object
#  1   age                                40 non-null     int64
#  2   Investment_Avenues                 40 non-null     object
#  3   Mutual_Funds                       40 non-null     int64
#  4   Equity_Market                      40 non-null     int64
#  5   Debentures                         40 non-null     int64
#  6   Government_Bonds                   40 non-null     int64
#  7   Fixed_Deposits                     40 non-null     int64
#  8   PPF                                40 non-null     int64
#  9   Gold                               40 non-null     int64
#  10  Stock_Marktet                      40 non-null     object
# ...

# %%
print("\nShape of the Dataset (Rows, Columns):", df.shape)
# Out:
# Shape of the Dataset (Rows, Columns): (40, 24)

# %%
print("\nData Types of Each Column:")
print(df.dtypes)
# Out:
# Data Types of Each Column:
# gender                               object
# age                                   int64
# Investment_Avenues                   object
# Mutual_Funds                          int64
# Equity_Market                         int64
# Debentures                            int64
# Government_Bonds                      int64
# Fixed_Deposits                        int64
# PPF                                   int64
# Gold                                  int64
# Stock_Marktet                        object
# Factor                               object
# Objective                            object
# Purpose                              object
# Duration                             object
# Invest_Monitor                       object
# Expect                               object
# Avenue                               object
# What are your savings objectives?    object
# Reason_Equity                        object
# Reason_Mutual                        object
# ...

# %% [markdown]
# # Task 2 : Gender Distribution

# %% [markdown]
# ## Visualize gender distribution in the dataset

# %%
import matplotlib.pyplot as plt

# %%
Gender = df["gender"]
Gender.count()
# Out:
# 40

# %%
Gender_counts = Gender.value_counts()

print("Gender Distribution:\n", Gender_counts)
# Out:
# Gender Distribution:
#  Male      25
# Female    15
# Name: gender, dtype: int64

# %%
plt.figure(figsize=(6, 4))
Gender_counts.plot(kind='bar', color=['#1f77b4', '#ff7f0e'])
plt.title('Gender Distribution (Bar Chart)', fontsize=14)
plt.xlabel('Gender', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.xticks(rotation=0, fontsize=10)
plt.show()

# %%
plt.figure(figsize=(6, 6))
Gender_counts.plot(
    kind='pie', 
    autopct='%1.1f%%', 
    startangle=90, 
    colors=['#1f77b4', '#ff7f0e'], 
    labels=Gender_counts.index
)
plt.title('Gender Distribution (Pie Chart)', fontsize=14)
plt.ylabel('')  # Remove y-axis label for a cleaner look
plt.show()

# %% [markdown]
# # Task 3 : Descriptive Statistics

# %% [markdown]
# ## Present basic statistics for numerical columns

# %%
numerical_columns = df.select_dtypes(include=['number'])
numerical_columns
# Out:
#     age  Mutual_Funds  Equity_Market  Debentures  Government_Bonds  \
# 0    34             1              2           5                 3
# 1    23             4              3           2                 1
# 2    30             3              6           4                 2
# 3    22             2              1           3                 7
# 4    24             2              1           3                 6
# 5    24             7              5           4                 6
# 6    27             3              6           4                 2
# 7    21             2              3           7                 4
# 8    35             2              4           7                 5
# 9    31             1              3           7                 4
# 10   35             2              4           7                 5
# 11   29             2              5           7                 6
# 12   21             1              2           3                 4
# ...

# %%
for column in numerical_columns.columns:
    mean_value = numerical_columns[column].mean()
    median_value = numerical_columns[column].median()
    std_value = numerical_columns[column].std()
        
    print(f"\nStatistics for '{column}' \n Mean: {mean_value} \n Median: {median_value} \n Standard Deviation: {std_value.round(4)}")
# Out:
# Statistics for 'age'
#  Mean: 27.8
#  Median: 27.0
#  Standard Deviation: 3.5605
#
# Statistics for 'Mutual_Funds'
#  Mean: 2.55
#  Median: 2.0
#  Standard Deviation: 1.1972
#
# Statistics for 'Equity_Market'
#  Mean: 3.475
#  Median: 4.0
#  Standard Deviation: 1.132
#
# Statistics for 'Debentures'
#  Mean: 5.75
#  Median: 6.5
#  Standard Deviation: 1.6756
#
# Statistics for 'Government_Bonds'
#  Mean: 4.65
#  Median: 5.0
#  Standard Deviation: 1.3691
#
# Statistics for 'Fixed_Deposits'
#  Mean: 3.575
#  Median: 3.5
#  Standard Deviation: 1.7958
#
# Statistics for 'PPF'
#  Mean: 2.025
#  Median: 1.0
#  Standard Deviation: 1.6091
#
# Statistics for 'Gold'
#  Mean: 5.975
#  Median: 6.0
#  Standard Deviation: 1.1433

# %% [markdown]
# # Task 4: Most Preferred Investment Avenue

# %% [markdown]
# ## Identify the most preferred investment avenue

# %%
Analyze_column = df[['Mutual_Funds', 'Equity_Market', 'Debentures', 'Government_Bonds', 'Fixed_Deposits', 'PPF', 'Gold']]

# %%
Analyze_column
# Out:
#     Mutual_Funds  Equity_Market  Debentures  Government_Bonds  Fixed_Deposits  \
# 0              1              2           5                 3               7
# 1              4              3           2                 1               5
# 2              3              6           4                 2               5
# 3              2              1           3                 7               6
# 4              2              1           3                 6               4
# 5              7              5           4                 6               3
# 6              3              6           4                 2               5
# 7              2              3           7                 4               6
# 8              2              4           7                 5               3
# 9              1              3           7                 4               5
# 10             2              4           7                 5               3
# ...

# %%
for column in Analyze_column.columns:
    frequency = df[column].value_counts()
    
    # Get the most frequent value and its count
    most_frequent_value = frequency.idxmax()
    highest_frequency = frequency.max()
    
    print(f"Column: {column}")
    print(f"Most frequent value: {most_frequent_value}, Frequency: {highest_frequency}")
    print('-' * 50)
# Out:
# Column: Mutual_Funds
# Most frequent value: 2, Frequency: 21
# --------------------------------------------------
# Column: Equity_Market
# Most frequent value: 4, Frequency: 16
# --------------------------------------------------
# Column: Debentures
# Most frequent value: 7, Frequency: 20
# --------------------------------------------------
# Column: Government_Bonds
# Most frequent value: 5, Frequency: 18
# --------------------------------------------------
# Column: Fixed_Deposits
# Most frequent value: 3, Frequency: 10
# --------------------------------------------------
# Column: PPF
# Most frequent value: 1, Frequency: 24
# --------------------------------------------------
# Column: Gold
# Most frequent value: 6, Frequency: 18
# --------------------------------------------------

# %% [markdown]
# # Task 5: Reasons for Investment

# %% [markdown]
# ## Analyze and summarize reasons for investment choices

# %%
reason_columns = df[['Reason_Equity', 'Reason_Mutual', 'Reason_Bonds', 'Reason_FD']]

# %%
reasons = reason_columns.stack().reset_index(drop=True)

# %%
reason_counts = reasons.value_counts()

# %%
print("Summary of Investment Reasons:\n", reason_counts)
# Out:
# Summary of Investment Reasons:
#  Capital Appreciation    30
# Assured Returns         26
# Better Returns          24
# Risk Free               19
# Fixed Returns           18
# Safe Investment         13
# Fund Diversification    13
# Dividend                 8
# High Interest Rates      3
# Tax Benefits             3
# Liquidity                2
# Tax Incentives           1
# dtype: int64

# %%
# Plotting a horizontal bar chart
plt.figure(figsize=(10, 6))
reason_counts.sort_values().plot(kind='barh', color='lightcoral')

# Adding labels and title
plt.title('Distribution of Investment Reasons (Horizontal Bar Chart)', fontsize=14)
plt.xlabel('Count', fontsize=12)
plt.ylabel('Investment Reasons', fontsize=12)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Summary:

# %% [markdown]
# 1. Most Common Reasons: "Capital Appreciation" is the most common reason, appearing 30 times across different columns.
# 2. Other Frequent Reasons: "Assured Returns", "Better Returns", and "Risk Free" are also frequently cited reasons.
# 3. Unique or Less Frequent Reasons: "Tax incentives", "Liquidity", "High Interest Rates", and "Tax Benefits" are mentioned less often, indicating they may be secondary considerations.

# %% [markdown]
# # Task 6 : Savings Objectives

# %% [markdown]
# ## Identify and present main savings objectives

# %%
Objective = df["What are your savings objectives?"]

# %%
unique_objective = Objective.unique()
print(f"Unique Savings Objectives:", unique_objective)
# Out:
# Unique Savings Objectives: ['Retirement Plan' 'Health Care' 'Education']

# %%
no_objective = Objective.value_counts()
print(f"\nEach Objective Counts:\n ", no_objective)
# Out:
# Each Objective Counts:
#   Retirement Plan    24
# Health Care        13
# Education           3
# Name: What are your savings objectives?, dtype: int64

# %%
objective_list = {
    'Retirement Plan': 'Saving money for use after retirement.',
    'Health Care': 'Saving for medical and health-related expenses.',
    'Education': 'Saving for education costs like tuition.'
}

# %%
print("\nObjective Descriptions:\n")

for objective, description in objective_list.items():
    print(f"{objective}: {description}")
# Out:
# Objective Descriptions:
#
# Retirement Plan: Saving money for use after retirement.
# Health Care: Saving for medical and health-related expenses.
# Education: Saving for education costs like tuition.

# %% [markdown]
# #  Task 7 : Common Information Sources

# %% [markdown]
# ## Analyze common sources participants rely on for investment information

# %%
source = df["Source"]

# %%
print("\nCommon Information Sources:\n", source.value_counts())
# Out:
# Common Information Sources:
#  Financial Consultants       16
# Newspapers and Magazines    14
# Television                   6
# Internet                     4
# Name: Source, dtype: int64

# %%
source_count = source.value_counts()

# %%
plt.figure(figsize=(10, 6))
source_count.plot(kind='bar', color='skyblue', edgecolor='black')
plt.title('Distribution of Sources', fontsize=16)
plt.xlabel('Information Sources', fontsize=14)
plt.ylabel('Frequency', fontsize=14)
plt.xticks(rotation=45, fontsize=12)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 8))
source_count.plot(
    kind ="pie",
    autopct='%1.1f%%',  
    colors=['#ff9999','#66b3ff','#99ff99','#ffcc99'], 
    wedgeprops={'edgecolor': 'black'}
)
plt.title('Distribution of Sources', fontsize=16)
plt.ylabel('') 
plt.tight_layout()
plt.show()

# %% [markdown]
# #  Task 8 : Investment Duration

# %% [markdown]
#  ## Calculate the average investment duration.

# %%
investment = df["Duration"]

# %%
investment
# Out:
# 0             1-3 years
# 1     More than 5 years
# 2             3-5 years
# 3      Less than 1 year
# 4      Less than 1 year
# 5             1-3 years
# 6             3-5 years
# 7             3-5 years
# 8             1-3 years
# 9             3-5 years
# 10            3-5 years
# 11            1-3 years
# 12            1-3 years
# 13            1-3 years
# 14            1-3 years
# 15            1-3 years
# 16            1-3 years
# 17            1-3 years
# 18            1-3 years
# 19            3-5 years
# 20            3-5 years
# 21            3-5 years
# 22            3-5 years
# 23            3-5 years
# 24            3-5 years
# 25            3-5 years
# 26            3-5 years
# 27            1-3 years
# 28            1-3 years
# 29            3-5 years
# 30            1-3 years
# 31            3-5 years
# 32            3-5 years
# 33            1-3 years
# 34            1-3 years
# 35            3-5 years
# 36            1-3 years
# 37            3-5 years
# ...

# %%
investment.value_counts()
# Out:
# 3-5 years            19
# 1-3 years            18
# Less than 1 year      2
# More than 5 years     1
# Name: Duration, dtype: int64

# %% [markdown]
# Since the Duration column in the dataset containig th ecatregorical value. So, in this case we have to handel it by converting into numerical values for meaningful analysis.

# %%
duration_format = {
    'Less than 1 year': 0.5,
    '1-3 years': 2,
    '3-5 years': 4,
    'More than 5 years': 6
}

# %%
df['duration_numeric'] = df['Duration'].map(duration_format)

# %%
df['duration_numeric']
# Out:
# 0     2.0
# 1     6.0
# 2     4.0
# 3     0.5
# 4     0.5
# 5     2.0
# 6     4.0
# 7     4.0
# 8     2.0
# 9     4.0
# 10    4.0
# 11    2.0
# 12    2.0
# 13    2.0
# 14    2.0
# 15    2.0
# 16    2.0
# 17    2.0
# 18    2.0
# 19    4.0
# 20    4.0
# 21    4.0
# 22    4.0
# 23    4.0
# 24    4.0
# 25    4.0
# 26    4.0
# 27    2.0
# 28    2.0
# 29    4.0
# 30    2.0
# 31    4.0
# 32    4.0
# 33    2.0
# 34    2.0
# 35    4.0
# 36    2.0
# 37    4.0
# 38    2.0
# 39    4.0
# Name: duration_numeric, dtype: float64

# %%
print("\nDataset with Numeric Durations:\n")
df
# Out:
# Dataset with Numeric Durations:
#     gender  age Investment_Avenues  Mutual_Funds  Equity_Market  Debentures  \
# 0   Female   34                Yes             1              2           5
# 1   Female   23                Yes             4              3           2
# 2     Male   30                Yes             3              6           4
# 3     Male   22                Yes             2              1           3
# 4   Female   24                 No             2              1           3
# 5   Female   24                 No             7              5           4
# 6   Female   27                Yes             3              6           4
# 7     Male   21                Yes             2              3           7
# 8     Male   35                Yes             2              4           7
# 9     Male   31                Yes             1              3           7
# 10  Female   35                Yes             2              4           7
# ...

# %%
average_duration = df['duration_numeric'].mean()

# %%
print(f"The Average Duration of Investment : {average_duration:.2f} years")
# Out:
# The Average Duration of Investment : 2.98 years

# %% [markdown]
# #  Task 9 : Expectations from Investments

# %% [markdown]
# ## Summarize participant's expectations from investments.

# %%
Expect = df["Expect"]

# %%
Expect
# Out:
# 0     20%-30%
# 1     20%-30%
# 2     20%-30%
# 3     10%-20%
# 4     20%-30%
# 5     30%-40%
# 6     20%-30%
# 7     20%-30%
# 8     20%-30%
# 9     30%-40%
# 10    20%-30%
# 11    20%-30%
# 12    20%-30%
# 13    20%-30%
# 14    20%-30%
# 15    20%-30%
# 16    20%-30%
# 17    20%-30%
# 18    20%-30%
# 19    20%-30%
# 20    20%-30%
# 21    20%-30%
# 22    20%-30%
# 23    20%-30%
# 24    30%-40%
# 25    20%-30%
# 26    20%-30%
# 27    20%-30%
# 28    20%-30%
# 29    10%-20%
# 30    10%-20%
# 31    20%-30%
# 32    30%-40%
# 33    20%-30%
# 34    20%-30%
# 35    20%-30%
# 36    20%-30%
# 37    30%-40%
# 38    20%-30%
# 39    20%-30%
# Name: Expect, dtype: object

# %%
Expect.value_counts()
# Out:
# 20%-30%    32
# 30%-40%     5
# 10%-20%     3
# Name: Expect, dtype: int64

# %%
expectation_description = {
    '30%-40%': "This group wants higher returns, meaning they’re willing to take on more risk for bigger rewards.",
    '20%-30%': "Participants expect moderate returns, usually from high-risk investments like stocks or mutual funds.",
    '10%-20%': "These participants expect lower returns, suggesting they prefer safer investments like bonds or fixed deposits."
}

# %%
for expectation, description in expectation_description.items():
    print(f"\nExpectation: {expectation} \nDescription: {description}")
# Out:
# Expectation: 30%-40%
# Description: This group wants higher returns, meaning they’re willing to take on more risk for bigger rewards.
#
# Expectation: 20%-30%
# Description: Participants expect moderate returns, usually from high-risk investments like stocks or mutual funds.
#
# Expectation: 10%-20%
# Description: These participants expect lower returns, suggesting they prefer safer investments like bonds or fixed deposits.

# %%
ex_p = Expect.value_counts()

plt.figure(figsize=(7, 7))
plt.pie(ex_p , labels=ex_p.index, autopct='%1.1f%%', startangle=90, colors=['#ff9999','#66b3ff','#99ff99'])
plt.title('Distribution of Investment Expectations')
plt.axis('equal')  # Equal aspect ratio ensures that pie chart is drawn as a circle.

plt.show()

# %% [markdown]
# # Task 10 : Correlation Analysis

# %% [markdown]
# ## Explore potential correlations between factors.

# %%
import seaborn as sb

# %%
# Convert "Expected Returns" to numerical values (taking the middle value of the range)
def convert_returns(return_range):
    low, high = return_range.replace('%', '').split('-')
    return (int(low) + int(high)) / 2

# %%
df['expect_num'] = df['Expect'].apply(convert_returns)

# %%
df['expect_num']
# Out:
# 0     25.0
# 1     25.0
# 2     25.0
# 3     15.0
# 4     25.0
# 5     35.0
# 6     25.0
# 7     25.0
# 8     25.0
# 9     35.0
# 10    25.0
# 11    25.0
# 12    25.0
# 13    25.0
# 14    25.0
# 15    25.0
# 16    25.0
# 17    25.0
# 18    25.0
# 19    25.0
# 20    25.0
# 21    25.0
# 22    25.0
# 23    25.0
# 24    35.0
# 25    25.0
# 26    25.0
# 27    25.0
# 28    25.0
# 29    15.0
# 30    15.0
# 31    25.0
# 32    35.0
# 33    25.0
# 34    25.0
# 35    25.0
# 36    25.0
# 37    35.0
# 38    25.0
# 39    25.0
# Name: expect_num, dtype: float64

# %%
correlation_matrix = df[['age', 'duration_numeric', 'expect_num']].corr()

# %%
print("Correlation Matrix:\n", correlation_matrix)
# Out:
# Correlation Matrix:
#                         age  duration_numeric  expect_num
# age               1.000000          0.051756   -0.089606
# duration_numeric  0.051756          1.000000    0.258223
# expect_num       -0.089606          0.258223    1.000000

# %%
# Visualize the correlation using a heatmap
plt.figure(figsize=(8, 6))
sb.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', cbar=True)
plt.title('Correlation Matrix between Age, Investment Duration, and Expected Returns')
plt.tight_layout()
plt.show()

# %%
# Scatter plots to visualize relationships
plt.figure(figsize=(12, 6))

# Scatter plot: Age vs. Investment Duration
plt.subplot(1, 2, 1)
plt.scatter(df['age'], df['duration_numeric'], color='skyblue')
plt.title('Age vs. Investment duration')
plt.xlabel('Age')
plt.ylabel('Investment Duration (Years)')
plt.grid(True)

# Scatter plot: Age vs. Expected Returns
plt.subplot(1, 2, 2)
plt.scatter(df['age'], df['expect_num'], color='salmon')
plt.title('Age vs. Expected returns')
plt.xlabel('Age')
plt.ylabel('Expected Returns (%)')
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
# 1. Pair Plot to visualize relationships between age, investment duration, and expected returns
sb.pairplot(df[['age', 'duration_numeric', 'expect_num']], kind='scatter', hue='age')
plt.suptitle('Pair Plot: Relationships between Age, Investment Duration, and Expected Returns', y=1.02)
plt.tight_layout()
plt.show()
